# %%
import kmodels as kmk
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
df = pd.read_pickle('../data/FormattedData_wPainAndOA.pkl')
df
# Out:
#            Fx        Fy        Fz       FPL       APL       EPL       EPB  \
# 0    0.346711  0.283910 -2.086856  0.302559  0.115935  0.087088  0.048929
# 1    0.334350  0.272250 -2.087275  0.302559  0.115935  0.087088  0.048992
# 2    0.367885  0.285303 -2.111033  0.302559  0.115935  0.087088  0.049063
# 3    0.371264  0.277671 -2.151635  0.302559  0.115935  0.087088  0.049127
# 4    0.370315  0.278336 -2.163308  0.302559  0.115935  0.087088  0.049192
# ..        ...       ...       ...       ...       ...       ...       ...
# 995 -0.257240 -0.064174 -0.951621  0.025482  0.194398  0.000022  0.221204
# 996 -0.248619 -0.076683 -0.936236  0.024978  0.192990  0.000023  0.221275
# 997 -0.258259 -0.062577 -0.935968  0.024459  0.191562  0.000023  0.221357
# 998 -0.259474 -0.098302 -0.986170  0.023970  0.190115  0.000023  0.221450
# 999 -0.252572 -0.082341 -0.963742  0.023494  0.188653  0.000023  0.221546
#
#           DIO       ADP       OPP       FPB Subject Event  Frame  Pain_Cohort  \
# 0    0.001397  0.053171  0.027892  0.321829    AO31     1      0            1
# 1    0.001556  0.053171  0.028178  0.322389    AO31     1      1            1
# 2    0.001717  0.053171  0.028445  0.322978    AO31     1      2            1
# 3    0.001879  0.053171  0.028732  0.323635    AO31     1      3            1
# 4    0.002044  0.053171  0.029015  0.324294    AO31     1      4            1
# ..        ...       ...       ...       ...     ...   ...    ...          ...
# 995  0.001004  0.001260  0.000000  0.000258    KE58     3    995            0
# 996  0.000989  0.001250  0.000000  0.000254    KE58     3    996            0
# 997  0.000973  0.001241  0.000000  0.000249    KE58     3    997            0
# 998  0.000959  0.001238  0.000000  0.000244    KE58     3    998            0
# 999  0.000958  0.001238  0.000007  0.000238    KE58     3    999            0
#
#      Eaton_Litter
# 0               3
# 1               3
# 2               3
# 3               3
# 4               3
# ..            ...
# 995             1
# 996             1
# 997             1
# 998             1
# 999             1
#
# [30000 rows x 16 columns]

# %%
# get all numerical columns
y_cols = ['Pain_Cohort']
Y = df[y_cols].to_numpy()
X = df.to_numpy()[:,0:11]
time = df['Frame'].to_numpy()
X = np.hstack((X, time.reshape(-1,1)))
X.shape, Y.shape
# Out:
# ((30000, 12), (30000, 1))

# %%
def get_data_by_subject(df):
    X = []
    Y = []
    y_cols = ['Pain_Cohort','Eaton_Litter']
    subjects = df['Subject'].unique()
    for i in subjects:
        X.append(df[df['Subject'] == i].to_numpy()[:,0:11].reshape(1, -1))
        pain_mean = df[df['Subject'] == i]['Pain_Cohort'].mean()
        Eaton_mean = df[df['Subject'] == i]['Eaton_Litter'].mean()
        Y.append(np.array([pain_mean, Eaton_mean]).reshape(1, -1))
    return np.vstack(X), np.vstack(Y)
X, Y = get_data_by_subject(df)
X = np.hstack((Y, X))
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
X.shape, Y.shape
# Out:
# ((10, 33002), (10, 2))

# %%
plt.plot(X[0])

# %%
plt.hist(Y[:,0])
plt.hist(Y[:,1])
# Out:
# (array([2., 0., 0., 2., 0., 0., 4., 0., 0., 2.]),
#  array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
config = {
    'estimator_type': 'VAE',
    'input_dim': X.shape[1],
    'is_VAE': True,
    'batch_size':5, 
    'epochs':1001, 
    'verbose':10,
    'latent_dim': 2,
    'lr_init':1e-4,
    'n_layers':3,
    'binary_dim':1,
}
reg = kmk.Trainer(**config)

# %%
def to_torch(X):
    if isinstance(X, np.ndarray):
        X = torch.from_numpy(X.astype(np.float32))
    elif isinstance(X, pd.DataFrame):
        X = X.values
        X = torch.from_numpy(X.astype(np.float32))
    return X
X = to_torch(X)
Y = to_torch(Y)
reg.fit(X, X)
# Out:
# ====> Epoch: 0 Average loss: 62125.062500000 Time: 0.66
# Loss components: {}
# ====> Epoch: 10 Average loss: 57871.027343750 Time: 0.56
# Loss components: {}
# ====> Epoch: 20 Average loss: 53293.496093750 Time: 0.51
# Loss components: {}
# ====> Epoch: 30 Average loss: 46073.554687500 Time: 0.50
# Loss components: {}
# ====> Epoch: 40 Average loss: 37546.718750000 Time: 0.49
# Loss components: {}
# ====> Epoch: 50 Average loss: 30570.417968750 Time: 0.47
# Loss components: {}
# ====> Epoch: 60 Average loss: 25669.724609375 Time: 0.46
# Loss components: {}
# ====> Epoch: 70 Average loss: 23275.845703125 Time: 0.48
# Loss components: {}
# ====> Epoch: 80 Average loss: 22005.183593750 Time: 0.46
# Loss components: {}
# ====> Epoch: 90 Average loss: 17513.257812500 Time: 0.46
# Loss components: {}
# ====> Epoch: 100 Average loss: 17863.841796875 Time: 0.53
# Loss components: {}
# ====> Epoch: 110 Average loss: 17550.160156250 Time: 0.46
# Loss components: {}
# ====> Epoch: 120 Average loss: 16631.058593750 Time: 0.44
# Loss components: {}
# ====> Epoch: 130 Average loss: 18070.791015625 Time: 0.49
# Loss components: {}
# ====> Epoch: 140 Average loss: 16506.660156250 Time: 0.49
# Loss components: {}
# ====> Epoch: 150 Average loss: 15724.384765625 Time: 0.46
# Loss components: {}
# ====> Epoch: 160 Average loss: 18174.263671875 Time: 0.46
# Loss components: {}
# ====> Epoch: 170 Average loss: 18890.074218750 Time: 0.83
# Loss components: {}
# ====> Epoch: 180 Average loss: 15685.926757812 Time: 0.46
# Loss components: {}
# ====> Epoch: 190 Average loss: 17975.187500000 Time: 0.50
# Loss components: {}
# ====> Epoch: 200 Average loss: 17730.156250000 Time: 0.53
# Loss components: {}
# ====> Epoch: 210 Average loss: 18999.810546875 Time: 0.46
# Loss components: {}
# ====> Epoch: 220 Average loss: 18600.859375000 Time: 0.50
# Loss components: {}
# ====> Epoch: 230 Average loss: 15412.116210938 Time: 0.51
# Loss components: {}
# ====> Epoch: 240 Average loss: 17379.986328125 Time: 0.46
# Loss components: {}
# ====> Epoch: 250 Average loss: 16668.609375000 Time: 0.46
# Loss components: {}
# ====> Epoch: 260 Average loss: 16657.832031250 Time: 0.49
# Loss components: {}
# ====> Epoch: 270 Average loss: 19153.531250000 Time: 0.45
# Loss components: {}
# ====> Epoch: 280 Average loss: 18837.734375000 Time: 0.47
# Loss components: {}
# ====> Epoch: 290 Average loss: 15662.835937500 Time: 0.46
# Loss components: {}
# ====> Epoch: 300 Average loss: 18592.810546875 Time: 0.50
# Loss components: {}
# ====> Epoch: 310 Average loss: 16984.781250000 Time: 0.49
# Loss components: {}
# ====> Epoch: 320 Average loss: 17442.537109375 Time: 0.51
# Loss components: {}
# ====> Epoch: 330 Average loss: 17751.492187500 Time: 0.52
# Loss components: {}
# ====> Epoch: 340 Average loss: 16779.556640625 Time: 0.46
# Loss components: {}
# ====> Epoch: 350 Average loss: 15967.379882812 Time: 0.46
# Loss components: {}
# ====> Epoch: 360 Average loss: 17179.289062500 Time: 0.48
# Loss components: {}
# ====> Epoch: 780 Average loss: 8809.670898438 Time: 0.46
# Loss components: {}
# ====> Epoch: 790 Average loss: 11047.327148438 Time: 0.48
# Loss components: {}
# ====> Epoch: 800 Average loss: 8370.154296875 Time: 0.50
# Loss components: {}
# ====> Epoch: 810 Average loss: 8454.076171875 Time: 0.46
# Loss components: {}
# ====> Epoch: 820 Average loss: 7443.539550781 Time: 0.45
# Loss components: {}
# ====> Epoch: 830 Average loss: 9760.366210938 Time: 0.48
# Loss components: {}
# ====> Epoch: 840 Average loss: 10074.967773438 Time: 0.46
# Loss components: {}
# ====> Epoch: 850 Average loss: 6668.927246094 Time: 0.47
# Loss components: {}
# ====> Epoch: 860 Average loss: 8134.087402344 Time: 0.49
# Loss components: {}
# ====> Epoch: 870 Average loss: 9831.374023438 Time: 0.46
# Loss components: {}
# ====> Epoch: 880 Average loss: 11483.199218750 Time: 0.46
# Loss components: {}
# ====> Epoch: 890 Average loss: 8582.018554688 Time: 0.48
# Loss components: {}
# ====> Epoch: 900 Average loss: 12165.429687500 Time: 0.56
# Loss components: {}
# ====> Epoch: 910 Average loss: 6658.352539062 Time: 0.45
# Loss components: {}
# ====> Epoch: 920 Average loss: 9057.557617188 Time: 0.45
# Loss components: {}
# ====> Epoch: 930 Average loss: 9924.960937500 Time: 0.49
# Loss components: {}
# ====> Epoch: 940 Average loss: 6993.866699219 Time: 0.47
# Loss components: {}
# ====> Epoch: 950 Average loss: 7348.441406250 Time: 0.47
# Loss components: {}
# ====> Epoch: 960 Average loss: 9569.978515625 Time: 0.49
# Loss components: {}
# ====> Epoch: 970 Average loss: 8671.315429688 Time: 0.47
# Loss components: {}
# ====> Epoch: 980 Average loss: 6258.057617188 Time: 0.45
# Loss components: {}
# ====> Epoch: 990 Average loss: 9142.480468750 Time: 0.46
# Loss components: {}
# ====> Epoch: 1000 Average loss: 7234.103027344 Time: 0.49
# Loss components: {}

# %%
plt.plot(reg.losses)

# %%
# get the encoded latent space and plot
X_encoded = reg.estimator.encode(X)[0].detach().numpy()
plt.scatter(X_encoded[:,0], X_encoded[:,1], c=Y[:,0], marker='*')

# %%
import plotly.express as px
# cmap is red to blue
# encoded_df 
Edf = pd.DataFrame(X_encoded[:, 0:2], columns=['x1', 'x2'])
Edf['Pain_Cohort'] = Y[:,0]
Edf['Eaton_Litter'] = Y[:,1]
# make the pain cohort categorical
Edf['Pain_Cohort'] = Edf['Pain_Cohort'].astype('category')
# now make the pain 1 category * and 0 category o
#Edf['Pain_Cohort'] = Edf['Pain_Cohort'].apply(lambda x: '*' if x == 1 else 'o')
fig = px.scatter(Edf, x='x1', y='x2', color='Eaton_Litter', symbol='Pain_Cohort', hover_data=['Eaton_Litter'])
# make the markers bigger with nicer backgrounds
fig.update_traces(marker=dict(size=12,
                                line=dict(width=2,
                                            color='DarkSlateGrey')),
                    selector=dict(mode='markers'))


fig.show()
# save as latent space.html
fig.write_html("latent_space.html")

# %%
reg.estimator
# get the number of learnable parameters
sum(p.numel() for p in reg.estimator.parameters() if p.requires_grad)
# Out:
# 5018106

# %%
pred = reg.estimator(X)[0].detach().numpy()
plt.plot(pred[0])
plt.plot(X[0], alpha=0.2)

# %%
plt.scatter(X.reshape(-1, 1), pred.reshape(-1, 1), edgecolors='k', alpha=0.2)
from sklearn.metrics import r2_score
r2_score(X.reshape(-1, 1), pred.reshape(-1, 1))
# Out:
# 0.5819410901709794
